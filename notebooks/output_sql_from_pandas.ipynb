# %% [markdown]
# # Introduction
#
# Creating a Postgres table using manual SQL from scratch is problematic, because the subsequent INSERT statement would throw errors due to data type mismatch. [`pandas.DataFrame.to_sql`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html) creates tables on the fly. Of course a `CREATE TABLE` query is automatically run. This notebook finds a way to get to this underlying `CREATE TABLE` query, so it can be used with [`airflow.providers.postgres.hooks.postgres`](https://airflow.apache.org/docs/apache-airflow-providers-postgres/stable/_api/airflow/providers/postgres/hooks/postgres/index.html#module-airflow.providers.postgres.hooks.postgres).
#
# The approach follow this [Stack Overflow answer](https://stackoverflow.com/questions/6350411/how-to-retrieve-executed-sql-code-from-sqlalchemy) is to run the `to_sql` method to upload some data to the database while also logging the information.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from datetime import datetime
import sqlalchemy as sa
import os
import gzip
import shutil
import requests
import pandas as pd
from pathlib import Path
from dotenv import (
    load_dotenv,
    find_dotenv
)
import psycopg2
from airflow.operators.python import PythonOperator
from airflow.providers.postgres.operators.postgres import PostgresOperator
from airflow.providers.postgres.hooks.postgres import PostgresHook
from src.data.database import (
    get_connection_string
)
from src.utils.utils import (
    stringify_columns
)

# %%
load_dotenv(find_dotenv())

project_dir = Path(find_dotenv()).parent
data_dir = project_dir / 'data'
raw_data_dir = data_dir / 'raw'
interim_data_dir = data_dir / 'interim'
reports_dir = project_dir / 'reports'

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Load data
#
# Test with the latest data set.

# %%
path = raw_data_dir / '2021-04-10.gz'
df = pd.read_csv(path, compression='gzip')

# %%
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  11156  https://www.airbnb.com/rooms/11156  20210410042103   2021-04-12
# 1  12351  https://www.airbnb.com/rooms/12351  20210410042103   2021-04-15
# 2  14250  https://www.airbnb.com/rooms/14250  20210410042103   2021-04-14
# 3  15253  https://www.airbnb.com/rooms/15253  20210410042103   2021-04-12
# 4  44545  https://www.airbnb.com/rooms/44545  20210410042103   2021-04-13
#
#                                                 name  \
# 0                               An Oasis in the City
# 1                  Sydney City & Harbour at the door
# 2                                Manly Harbour House
# 3  Unique Designer Rooftop Apartment in City Loca...
# 4             Sunny Darlinghurst Warehouse Apartment
#
#                                          description  \
# 0  Very central to the city which can be reached ...
# 1  Come stay with Vinh & Stuart (Awarded as one o...
# 2  Beautifully renovated, spacious and quiet, our...
# 3  Penthouse living at it best ... You will be st...
# 4  Sunny warehouse/loft apartment in the heart of...
#
#                                neighborhood_overview  \
# 0  It is very close to everything and everywhere,...
# 1  Pyrmont is an inner-city village of Sydney, on...
# 2  Balgowlah Heights is one of the most prestigio...
# 3  The location is really central and there is nu...
# 4  Darlinghurst is home to some of Sydney's best ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/2797669/17895...    40855
# 1  https://a0.muscache.com/pictures/763ad5c8-c951...    17061
# 2  https://a0.muscache.com/pictures/56935671/fdb8...    55948
# 3  https://a0.muscache.com/pictures/46dcb8a1-5d5b...    59850
# 4  https://a0.muscache.com/pictures/a88d8e14-4f63...   112237
#
#                                    host_url host_name  host_since  \
# 0   https://www.airbnb.com/users/show/40855   Colleen  2009-09-23
# 1   https://www.airbnb.com/users/show/17061    Stuart  2009-05-14
# 2   https://www.airbnb.com/users/show/55948     Heidi  2009-11-20
# 3   https://www.airbnb.com/users/show/59850     Morag  2009-12-03
# 4  https://www.airbnb.com/users/show/112237     Atari  2010-04-22
#
#                              host_location  \
# 0  Potts Point, New South Wales, Australia
# 1       Sydney, New South Wales, Australia
# 2       Sydney, New South Wales, Australia
# 3       Sydney, New South Wales, Australia
# 4       Sydney, New South Wales, Australia
#
#                                           host_about  host_response_time  \
# 0  Recently retired, I've lived & worked on 4 con...                 NaN
# 1  G'Day from Australia!\r\n\r\nHe's Vinh, and I'...                 NaN
# 2  I am a Canadian who has made Australia her hom...  within a few hours
# 3  I am originally Scottish but I have made Sydne...      within an hour
# 4  Curious about the world and full of wanderlust...                 NaN
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1                NaN                  NaN                 f
# 2                90%                  79%                 t
# 3                90%                  95%                 f
# 4                NaN                  NaN                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/40855/profile...
# 1  https://a0.muscache.com/im/users/17061/profile...
# 2  https://a0.muscache.com/im/users/55948/profile...
# 3  https://a0.muscache.com/im/pictures/user/730ee...
# 4  https://a0.muscache.com/im/pictures/user/34708...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/40855/profile...        Potts Point
# 1  https://a0.muscache.com/im/users/17061/profile...            Pyrmont
# 2  https://a0.muscache.com/im/users/55948/profile...          Balgowlah
# 3  https://a0.muscache.com/im/pictures/user/730ee...       Darlinghurst
# 4  https://a0.muscache.com/im/pictures/user/34708...       Darlinghurst
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  2.0                        2.0
# 2                  2.0                        2.0
# 3                  3.0                        3.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0                      ['email', 'phone', 'reviews']                    t
# 1  ['email', 'phone', 'manual_online', 'reviews',...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 4  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified                             neighbourhood  \
# 0                      f   Potts Point, New South Wales, Australia
# 1                      t       Pyrmont, New South Wales, Australia
# 2                      t     Balgowlah, New South Wales, Australia
# 3                      t  Darlinghurst, New South Wales, Australia
# 4                      t  Darlinghurst, New South Wales, Australia
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  longitude  \
# 0                 Sydney                           NaN -33.86767  151.22497
# 1                 Sydney                           NaN -33.86490  151.19171
# 2                  Manly                           NaN -33.80084  151.26378
# 3                 Sydney                           NaN -33.87964  151.21680
# 4                 Sydney                           NaN -33.87888  151.21439
#
#                property_type        room_type  accommodates  bathrooms  \
# 0  Private room in apartment     Private room             1        NaN
# 1  Private room in townhouse     Private room             2        NaN
# 2               Entire house  Entire home/apt             6        NaN
# 3  Private room in apartment     Private room             2        NaN
# 4                Entire loft  Entire home/apt             2        NaN
#
#    bathrooms_text  bedrooms  beds  \
# 0   1 shared bath       1.0   0.0
# 1   1 shared bath       1.0   1.0
# 2         3 baths       3.0   3.0
# 3  1 private bath       1.0   1.0
# 4          1 bath       1.0   1.0
#
#                                            amenities       price  \
# 0  ["Dishwasher", "Backyard", "Kitchen", "Shower ...      $65.00
# 1  ["Microwave", "Patio or balcony", "Wifi", "Dis...  $14,315.00
# 2  ["Stove", "Dedicated workspace", "Iron", "Pati...     $470.00
# 3  ["Dishwasher", "Kitchen", "Shower gel", "Cooki...      $80.00
# 4  ["Dishwasher", "Kitchen", "Cooking basics", "C...     $130.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               2             180                       2
# 1               2               7                       2
# 2               5              22                       5
# 3               2              90                       2
# 4               3             365                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       2                     180                     180
# 1                       2                       7                       7
# 2                       5                      22                      22
# 3                       2                      90                      90
# 4                       3                     365                     365
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                     2.0                   180.0               NaN
# 1                     2.0                     7.0               NaN
# 2                     5.0                    22.0               NaN
# 3                     2.0                    90.0               NaN
# 4                     3.0                   365.0               NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               29               59               89
# 1                t                0                0                0
# 2                t                0                0                0
# 3                t               21               48               78
# 4                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               364            2021-04-12                196
# 1                 0            2021-04-15                526
# 2               122            2021-04-14                  2
# 3               336            2021-04-12                367
# 4                 0            2021-04-13                 76
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                      0                       0   2009-12-05  2020-03-13
# 1                      0                       0   2010-07-24  2019-09-22
# 2                      0                       0   2016-01-02  2019-01-02
# 3                      3                       0   2012-02-23  2021-03-07
# 4                      0                       0   2010-10-20  2020-01-03
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  92.0                    10.0                        9.0
# 1                  95.0                    10.0                       10.0
# 2                  90.0                     8.0                        8.0
# 3                  88.0                    10.0                        9.0
# 4                  97.0                    10.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                   10.0                         10.0                    10.0
# 2                    9.0                          8.0                     9.0
# 3                   10.0                         10.0                    10.0
# 4                   10.0                         10.0                    10.0
#
#    review_scores_value  license instant_bookable  \
# 0                 10.0      NaN                f
# 1                 10.0      NaN                f
# 2                  8.0      NaN                f
# 3                  9.0      NaN                t
# 4                 10.0      NaN                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
# 2                               2
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             2
# 2                                             0
# 3                                             1
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.42
# 1                                            0               4.03
# 2                                            0               0.03
# 3                                            0               3.30
# 4                                            0               0.60

# %% [markdown]
# # Connect to Postgres

# %%
conn_string = get_connection_string()
engine = sa.create_engine(conn_string)
engine
# Out:
# Engine(postgresql+psycopg2://airflow:***@postgres:5432/airflow)

# %%
logging.basicConfig(filename='db.log')
logging.getLogger('sqlalchemy.engine').setLevel(logging.INFO)

# %%
df.loc[:, 'execution_date'] = datetime(2021, 3, 1)

# %%
stringify_columns(df.columns)
# Out:
# '    id, \n    listing_url, \n    scrape_id, \n    last_scraped, \n    name, \n    description, \n    neighborhood_overview, \n    picture_url, \n    host_id, \n    host_url, \n    host_name, \n    host_since, \n    host_location, \n    host_about, \n    host_response_time, \n    host_response_rate, \n    host_acceptance_rate, \n    host_is_superhost, \n    host_thumbnail_url, \n    host_picture_url, \n    host_neighbourhood, \n    host_listings_count, \n    host_total_listings_count, \n    host_verifications, \n    host_has_profile_pic, \n    host_identity_verified, \n    neighbourhood, \n    neighbourhood_cleansed, \n    neighbourhood_group_cleansed, \n    latitude, \n    longitude, \n    property_type, \n    room_type, \n    accommodates, \n    bathrooms, \n    bathrooms_text, \n    bedrooms, \n    beds, \n    amenities, \n    price, \n    minimum_nights, \n    maximum_nights, \n    minimum_minimum_nights, \n    maximum_minimum_nights, \n    minimum_maximum_nights, \n    maximum_maximum_nights, \n    minimum_nights_avg_ntm, \n    maximum_nights_avg_ntm, \n    calendar_updated, \n    has_availability, \n    availability_30, \n    availability_60, \n    availability_90, \n    availability_365, \n    calendar_last_scraped, \n    number_of_reviews, \n    number_of_reviews_ltm, \n    number_of_reviews_l30d, \n    first_review, \n    last_review, \n    review_scores_rating, \n    review_scores_accuracy, \n    review_scores_cleanliness, \n    review_scores_checkin, \n    review_scores_communication, \n    review_scores_location, \n    review_scores_value, \n    license, \n    instant_bookable, \n    calculated_host_listings_count, \n    calculated_host_listings_count_entire_homes, \n    calculated_host_listings_count_private_rooms, \n    calculated_host_listings_count_shared_rooms, \n    reviews_per_month, \n    execution_date'

# %%
df.head().to_sql(con=engine,
                 name='test_upload',
                 schema='raw',
                 if_exists='replace')
# Out:
# [2021-05-20 04:18:17,861] {base.py:132} INFO - select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where n.nspname=%(schema)s and relname=%(name)s
# [2021-05-20 04:18:17,862] {base.py:132} INFO - [cached since 1740s ago] {'schema': 'raw', 'name': 'test_upload'}
# [2021-05-20 04:18:17,871] {base.py:132} INFO - BEGIN (implicit)
# [2021-05-20 04:18:17,876] {base.py:132} INFO -
# CREATE TABLE raw.test_upload (
# 	index BIGINT,
# 	id BIGINT,
# 	listing_url TEXT,
# 	scrape_id BIGINT,
# 	last_scraped TEXT,
# 	name TEXT,
# 	description TEXT,
# 	neighborhood_overview TEXT,
# 	picture_url TEXT,
# 	host_id BIGINT,
# 	host_url TEXT,
# 	host_name TEXT,
# 	host_since TEXT,
# 	host_location TEXT,
# 	host_about TEXT,
# 	host_response_time TEXT,
# 	host_response_rate TEXT,
# 	host_acceptance_rate TEXT,
# 	host_is_superhost TEXT,
# 	host_thumbnail_url TEXT,
# 	host_picture_url TEXT,
# 	host_neighbourhood TEXT,
# 	host_listings_count FLOAT(53),
# 	host_total_listings_count FLOAT(53),
# 	host_verifications TEXT,
# 	host_has_profile_pic TEXT,
# 	host_identity_verified TEXT,
# 	neighbourhood TEXT,
# 	neighbourhood_cleansed TEXT,
# 	neighbourhood_group_cleansed FLOAT(53),
# 	latitude FLOAT(53),
# 	longitude FLOAT(53),
# 	property_type TEXT,
# 	room_type TEXT,
# 	accommodates BIGINT,
# 	bathrooms FLOAT(53),
# 	bathrooms_text TEXT,
# 	bedrooms FLOAT(53),
# 	beds FLOAT(53),
# 	amenities TEXT,
# 	price TEXT,
# 	minimum_nights BIGINT,
# 	maximum_nights BIGINT,
# 	minimum_minimum_nights BIGINT,
# 	maximum_minimum_nights BIGINT,
# 	minimum_maximum_nights BIGINT,
# 	maximum_maximum_nights BIGINT,
# 	minimum_nights_avg_ntm FLOAT(53),
# 	maximum_nights_avg_ntm FLOAT(53),
# 	calendar_updated FLOAT(53),
# 	has_availability TEXT,
# 	availability_30 BIGINT,
# 	availability_60 BIGINT,
# 	availability_90 BIGINT,
# 	availability_365 BIGINT,
# 	calendar_last_scraped TEXT,
# 	number_of_reviews BIGINT,
# 	number_of_reviews_ltm BIGINT,
# 	number_of_reviews_l30d BIGINT,
# 	first_review TEXT,
# 	last_review TEXT,
# 	review_scores_rating FLOAT(53),
# 	review_scores_accuracy FLOAT(53),
# 	review_scores_cleanliness FLOAT(53),
# 	review_scores_checkin FLOAT(53),
# 	review_scores_communication FLOAT(53),
# 	review_scores_location FLOAT(53),
# 	review_scores_value FLOAT(53),
# 	license FLOAT(53),
# 	instant_bookable TEXT,
# 	calculated_host_listings_count BIGINT,
# 	calculated_host_listings_count_entire_homes BIGINT,
# 	calculated_host_listings_count_private_rooms BIGINT,
# 	calculated_host_listings_count_shared_rooms BIGINT,
# 	reviews_per_month FLOAT(53),
# 	execution_date TIMESTAMP WITHOUT TIME ZONE
# )
#
#
# [2021-05-20 04:18:17,895] {base.py:132} INFO - [no key 0.01913s] {}
# [2021-05-20 04:18:17,901] {base.py:132} INFO - CREATE INDEX ix_raw_test_upload_index ON raw.test_upload (index)
# [2021-05-20 04:18:17,902] {base.py:132} INFO - [no key 0.00083s] {}
# [2021-05-20 04:18:17,908] {base.py:132} INFO - COMMIT
# [2021-05-20 04:18:17,918] {base.py:132} INFO - BEGIN (implicit)
# [2021-05-20 04:18:17,922] {base.py:132} INFO - INSERT INTO raw.test_upload (index, id, listing_url, scrape_id, last_scraped, name, description, neighborhood_overview, picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, license, instant_bookable, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month, execution_date) VALUES (%(index)s, %(id)s, %(listing_url)s, %(scrape_id)s, %(last_scraped)s, %(name)s, %(description)s, %(neighborhood_overview)s, %(picture_url)s, %(host_id)s, %(host_url)s, %(host_name)s, %(host_since)s, %(host_location)s, %(host_about)s, %(host_response_time)s, %(host_response_rate)s, %(host_acceptance_rate)s, %(host_is_superhost)s, %(host_thumbnail_url)s, %(host_picture_url)s, %(host_neighbourhood)s, %(host_listings_count)s, %(host_total_listings_count)s, %(host_verifications)s, %(host_has_profile_pic)s, %(host_identity_verified)s, %(neighbourhood)s, %(neighbourhood_cleansed)s, %(neighbourhood_group_cleansed)s, %(latitude)s, %(longitude)s, %(property_type)s, %(room_type)s, %(accommodates)s, %(bathrooms)s, %(bathrooms_text)s, %(bedrooms)s, %(beds)s, %(amenities)s, %(price)s, %(minimum_nights)s, %(maximum_nights)s, %(minimum_minimum_nights)s, %(maximum_minimum_nights)s, %(minimum_maximum_nights)s, %(maximum_maximum_nights)s, %(minimum_nights_avg_ntm)s, %(maximum_nights_avg_ntm)s, %(calendar_updated)s, %(has_availability)s, %(availability_30)s, %(availability_60)s, %(availability_90)s, %(availability_365)s, %(calendar_last_scraped)s, %(number_of_reviews)s, %(number_of_reviews_ltm)s, %(number_of_reviews_l30d)s, %(first_review)s, %(last_review)s, %(review_scores_rating)s, %(review_scores_accuracy)s, %(review_scores_cleanliness)s, %(review_scores_checkin)s, %(review_scores_communication)s, %(review_scores_location)s, %(review_scores_value)s, %(license)s, %(instant_bookable)s, %(calculated_host_listings_count)s, %(calculated_host_listings_count_entire_homes)s, %(calculated_host_listings_count_private_rooms)s, %(calculated_host_listings_count_shared_rooms)s, %(reviews_per_month)s, %(execution_date)s)
# [2021-05-20 04:18:17,923] {base.py:132} INFO - [generated in 0.00153s] ({'index': 0, 'id': 11156, 'listing_url': 'https://www.airbnb.com/rooms/11156', 'scrape_id': 20210410042103, 'last_scraped': '2021-04-12', 'name': 'An Oasis in the City', 'description': "Very central to the city which can be reached by an easy walk or by bus, with transport at the door, if required, and all amenities within easy reach ... (702 characters truncated) ... e historic Rocks area (& the markets on Saturday & Sunday)<br /><br />It is 7 minutes walk to the Kings Cross.train (Metro) station & buses to the be", 'neighborhood_overview': 'It is very close to everything and everywhere, has  many trees along the streets and is in a beautiful part of the city', 'picture_url': 'https://a0.muscache.com/pictures/2797669/17895d03_original.jpg', 'host_id': 40855, 'host_url': 'https://www.airbnb.com/users/show/40855', 'host_name': 'Colleen', 'host_since': '2009-09-23', 'host_location': 'Potts Point, New South Wales, Australia', 'host_about': "Recently retired, I've lived & worked on 4 continents & over the years have travelled thru about 50 countries. I live in inner-Sydney within walking  ... (47 characters truncated) ... ich are approx. 30 minutes. away on public transport).  Interests are travelling, wildlife, reading,snorkelling, theatre, ballet & interesting food. ", 'host_response_time': None, 'host_response_rate': None, 'host_acceptance_rate': None, 'host_is_superhost': 'f', 'host_thumbnail_url': 'https://a0.muscache.com/im/users/40855/profile_pic/1259121939/original.jpg?aki_policy=profile_small', 'host_picture_url': 'https://a0.muscache.com/im/users/40855/profile_pic/1259121939/original.jpg?aki_policy=profile_x_medium', 'host_neighbourhood': 'Potts Point', 'host_listings_count': 1.0, 'host_total_listings_count': 1.0, 'host_verifications': "['email', 'phone', 'reviews']", 'host_has_profile_pic': 't', 'host_identity_verified': 'f', 'neighbourhood': 'Potts Point, New South Wales, Australia', 'neighbourhood_cleansed': 'Sydney', 'neighbourhood_group_cleansed': None, 'latitude': -33.86767, 'longitude': 151.22497, 'property_type': 'Private room in apartment', 'room_type': 'Private room', 'accommodates': 1, 'bathrooms': None, 'bathrooms_text': '1 shared bath', 'bedrooms': 1.0, 'beds': 0.0, 'amenities': '["Dishwasher", "Backyard", "Kitchen", "Shower gel", "Cooking basics", "Hair dryer", "Bed linens", "Oven", "Stove", "Elevator", "Single level home", " ... (108 characters truncated) ... , "Shampoo", "Essentials", "Iron", "Long term stays allowed", "Hot water", "Refrigerator", "Wifi", "Dishes and silverware", "Patio or balcony", "TV"]', 'price': '$65.00', 'minimum_nights': 2, 'maximum_nights': 180, 'minimum_minimum_nights': 2, 'maximum_minimum_nights': 2, 'minimum_maximum_nights': 180, 'maximum_maximum_nights': 180, 'minimum_nights_avg_ntm': 2.0, 'maximum_nights_avg_ntm': 180.0, 'calendar_updated': None, 'has_availability': 't', 'availability_30': 29, 'availability_60': 59, 'availability_90': 89, 'availability_365': 364, 'calendar_last_scraped': '2021-04-12', 'number_of_reviews': 196, 'number_of_reviews_ltm': 0, 'number_of_reviews_l30d': 0, 'first_review': '2009-12-05', 'last_review': '2020-03-13', 'review_scores_rating': 92.0, 'review_scores_accuracy': 10.0, 'review_scores_cleanliness': 9.0, 'review_scores_checkin': 10.0, 'review_scores_communication': 10.0, 'review_scores_location': 10.0, 'review_scores_value': 10.0, 'license': None, 'instant_bookable': 'f', 'calculated_host_listings_count': 1, 'calculated_host_listings_count_entire_homes': 0, 'calculated_host_listings_count_private_rooms': 1, 'calculated_host_listings_count_shared_rooms': 0, 'reviews_per_month': 1.42, 'execution_date': datetime.datetime(2021, 3, 1, 0, 0)}, {'index': 1, 'id': 12351, 'listing_url': 'https://www.airbnb.com/rooms/12351', 'scrape_id': 20210410042103, 'last_scraped': '2021-04-15', 'name': 'Sydney City & Harbour at the door', 'description': "Come stay with Vinh & Stuart (Awarded as on ...
# [2021-05-20 04:18:17,928] {base.py:132} INFO - COMMIT

# %% [markdown]
# ## `if_exists='append'`

# %%
df.head().to_sql(con=engine,
                 name='test_upload',
                 schema='raw',
                 if_exists='append')
# Out:
# [2021-05-21 02:38:26,131] {base.py:132} INFO - select version()
# [2021-05-21 02:38:26,132] {base.py:132} INFO - [raw sql] {}
# [2021-05-21 02:38:26,134] {base.py:132} INFO - select current_schema()
# [2021-05-21 02:38:26,134] {base.py:132} INFO - [raw sql] {}
# [2021-05-21 02:38:26,136] {base.py:132} INFO - show standard_conforming_strings
# [2021-05-21 02:38:26,137] {base.py:132} INFO - [raw sql] {}
# [2021-05-21 02:38:26,141] {base.py:132} INFO - select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where n.nspname=%(schema)s and relname=%(name)s
# [2021-05-21 02:38:26,142] {base.py:132} INFO - [generated in 0.00134s] {'schema': 'raw', 'name': 'test_upload'}
# [2021-05-21 02:38:26,151] {base.py:132} INFO - BEGIN (implicit)
# [2021-05-21 02:38:26,157] {base.py:132} INFO -
# CREATE TABLE raw.test_upload (
# 	index BIGINT,
# 	id BIGINT,
# 	listing_url TEXT,
# 	scrape_id BIGINT,
# 	last_scraped TEXT,
# 	name TEXT,
# 	description TEXT,
# 	neighborhood_overview TEXT,
# 	picture_url TEXT,
# 	host_id BIGINT,
# 	host_url TEXT,
# 	host_name TEXT,
# 	host_since TEXT,
# 	host_location TEXT,
# 	host_about TEXT,
# 	host_response_time TEXT,
# 	host_response_rate TEXT,
# 	host_acceptance_rate TEXT,
# 	host_is_superhost TEXT,
# 	host_thumbnail_url TEXT,
# 	host_picture_url TEXT,
# 	host_neighbourhood TEXT,
# 	host_listings_count FLOAT(53),
# 	host_total_listings_count FLOAT(53),
# 	host_verifications TEXT,
# 	host_has_profile_pic TEXT,
# 	host_identity_verified TEXT,
# 	neighbourhood TEXT,
# 	neighbourhood_cleansed TEXT,
# 	neighbourhood_group_cleansed FLOAT(53),
# 	latitude FLOAT(53),
# 	longitude FLOAT(53),
# 	property_type TEXT,
# 	room_type TEXT,
# 	accommodates BIGINT,
# 	bathrooms FLOAT(53),
# 	bathrooms_text TEXT,
# 	bedrooms FLOAT(53),
# 	beds FLOAT(53),
# 	amenities TEXT,
# 	price TEXT,
# 	minimum_nights BIGINT,
# 	maximum_nights BIGINT,
# 	minimum_minimum_nights BIGINT,
# 	maximum_minimum_nights BIGINT,
# 	minimum_maximum_nights BIGINT,
# 	maximum_maximum_nights BIGINT,
# 	minimum_nights_avg_ntm FLOAT(53),
# 	maximum_nights_avg_ntm FLOAT(53),
# 	calendar_updated FLOAT(53),
# 	has_availability TEXT,
# 	availability_30 BIGINT,
# 	availability_60 BIGINT,
# 	availability_90 BIGINT,
# 	availability_365 BIGINT,
# 	calendar_last_scraped TEXT,
# 	number_of_reviews BIGINT,
# 	number_of_reviews_ltm BIGINT,
# 	number_of_reviews_l30d BIGINT,
# 	first_review TEXT,
# 	last_review TEXT,
# 	review_scores_rating FLOAT(53),
# 	review_scores_accuracy FLOAT(53),
# 	review_scores_cleanliness FLOAT(53),
# 	review_scores_checkin FLOAT(53),
# 	review_scores_communication FLOAT(53),
# 	review_scores_location FLOAT(53),
# 	review_scores_value FLOAT(53),
# 	license FLOAT(53),
# 	instant_bookable TEXT,
# 	calculated_host_listings_count BIGINT,
# 	calculated_host_listings_count_entire_homes BIGINT,
# 	calculated_host_listings_count_private_rooms BIGINT,
# 	calculated_host_listings_count_shared_rooms BIGINT,
# 	reviews_per_month FLOAT(53)
# )
#
#
# [2021-05-21 02:38:26,158] {base.py:132} INFO - [no key 0.00144s] {}
# [2021-05-21 02:38:26,169] {base.py:132} INFO - CREATE INDEX ix_raw_test_upload_index ON raw.test_upload (index)
# [2021-05-21 02:38:26,170] {base.py:132} INFO - [no key 0.00119s] {}
# [2021-05-21 02:38:26,178] {base.py:132} INFO - COMMIT
# [2021-05-21 02:38:26,192] {base.py:132} INFO - BEGIN (implicit)
# [2021-05-21 02:38:26,196] {base.py:132} INFO - INSERT INTO raw.test_upload (index, id, listing_url, scrape_id, last_scraped, name, description, neighborhood_overview, picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, license, instant_bookable, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month) VALUES (%(index)s, %(id)s, %(listing_url)s, %(scrape_id)s, %(last_scraped)s, %(name)s, %(description)s, %(neighborhood_overview)s, %(picture_url)s, %(host_id)s, %(host_url)s, %(host_name)s, %(host_since)s, %(host_location)s, %(host_about)s, %(host_response_time)s, %(host_response_rate)s, %(host_acceptance_rate)s, %(host_is_superhost)s, %(host_thumbnail_url)s, %(host_picture_url)s, %(host_neighbourhood)s, %(host_listings_count)s, %(host_total_listings_count)s, %(host_verifications)s, %(host_has_profile_pic)s, %(host_identity_verified)s, %(neighbourhood)s, %(neighbourhood_cleansed)s, %(neighbourhood_group_cleansed)s, %(latitude)s, %(longitude)s, %(property_type)s, %(room_type)s, %(accommodates)s, %(bathrooms)s, %(bathrooms_text)s, %(bedrooms)s, %(beds)s, %(amenities)s, %(price)s, %(minimum_nights)s, %(maximum_nights)s, %(minimum_minimum_nights)s, %(maximum_minimum_nights)s, %(minimum_maximum_nights)s, %(maximum_maximum_nights)s, %(minimum_nights_avg_ntm)s, %(maximum_nights_avg_ntm)s, %(calendar_updated)s, %(has_availability)s, %(availability_30)s, %(availability_60)s, %(availability_90)s, %(availability_365)s, %(calendar_last_scraped)s, %(number_of_reviews)s, %(number_of_reviews_ltm)s, %(number_of_reviews_l30d)s, %(first_review)s, %(last_review)s, %(review_scores_rating)s, %(review_scores_accuracy)s, %(review_scores_cleanliness)s, %(review_scores_checkin)s, %(review_scores_communication)s, %(review_scores_location)s, %(review_scores_value)s, %(license)s, %(instant_bookable)s, %(calculated_host_listings_count)s, %(calculated_host_listings_count_entire_homes)s, %(calculated_host_listings_count_private_rooms)s, %(calculated_host_listings_count_shared_rooms)s, %(reviews_per_month)s)
# [2021-05-21 02:38:26,197] {base.py:132} INFO - [generated in 0.00148s] ({'index': 0, 'id': 11156, 'listing_url': 'https://www.airbnb.com/rooms/11156', 'scrape_id': 20210410042103, 'last_scraped': '2021-04-12', 'name': 'An Oasis in the City', 'description': "Very central to the city which can be reached by an easy walk or by bus, with transport at the door, if required, and all amenities within easy reach ... (702 characters truncated) ... e historic Rocks area (& the markets on Saturday & Sunday)<br /><br />It is 7 minutes walk to the Kings Cross.train (Metro) station & buses to the be", 'neighborhood_overview': 'It is very close to everything and everywhere, has  many trees along the streets and is in a beautiful part of the city', 'picture_url': 'https://a0.muscache.com/pictures/2797669/17895d03_original.jpg', 'host_id': 40855, 'host_url': 'https://www.airbnb.com/users/show/40855', 'host_name': 'Colleen', 'host_since': '2009-09-23', 'host_location': 'Potts Point, New South Wales, Australia', 'host_about': "Recently retired, I've lived & worked on 4 continents & over the years have travelled thru about 50 countries. I live in inner-Sydney within walking  ... (47 characters truncated) ... ich are approx. 30 minutes. away on public transport).  Interests are travelling, wildlife, reading,snorkelling, theatre, ballet & interesting food. ", 'host_response_time': None, 'host_response_rate': None, 'host_acceptance_rate': None, 'host_is_superhost': 'f', 'host_thumbnail_url': 'https://a0.muscache.com/im/users/40855/profile_pic/1259121939/original.jpg?aki_policy=profile_small', 'host_picture_url': 'https://a0.muscache.com/im/users/40855/profile_pic/1259121939/original.jpg?aki_policy=profile_x_medium', 'host_neighbourhood': 'Potts Point', 'host_listings_count': 1.0, 'host_total_listings_count': 1.0, 'host_verifications': "['email', 'phone', 'reviews']", 'host_has_profile_pic': 't', 'host_identity_verified': 'f', 'neighbourhood': 'Potts Point, New South Wales, Australia', 'neighbourhood_cleansed': 'Sydney', 'neighbourhood_group_cleansed': None, 'latitude': -33.86767, 'longitude': 151.22497, 'property_type': 'Private room in apartment', 'room_type': 'Private room', 'accommodates': 1, 'bathrooms': None, 'bathrooms_text': '1 shared bath', 'bedrooms': 1.0, 'beds': 0.0, 'amenities': '["Dishwasher", "Backyard", "Kitchen", "Shower gel", "Cooking basics", "Hair dryer", "Bed linens", "Oven", "Stove", "Elevator", "Single level home", " ... (108 characters truncated) ... , "Shampoo", "Essentials", "Iron", "Long term stays allowed", "Hot water", "Refrigerator", "Wifi", "Dishes and silverware", "Patio or balcony", "TV"]', 'price': '$65.00', 'minimum_nights': 2, 'maximum_nights': 180, 'minimum_minimum_nights': 2, 'maximum_minimum_nights': 2, 'minimum_maximum_nights': 180, 'maximum_maximum_nights': 180, 'minimum_nights_avg_ntm': 2.0, 'maximum_nights_avg_ntm': 180.0, 'calendar_updated': None, 'has_availability': 't', 'availability_30': 29, 'availability_60': 59, 'availability_90': 89, 'availability_365': 364, 'calendar_last_scraped': '2021-04-12', 'number_of_reviews': 196, 'number_of_reviews_ltm': 0, 'number_of_reviews_l30d': 0, 'first_review': '2009-12-05', 'last_review': '2020-03-13', 'review_scores_rating': 92.0, 'review_scores_accuracy': 10.0, 'review_scores_cleanliness': 9.0, 'review_scores_checkin': 10.0, 'review_scores_communication': 10.0, 'review_scores_location': 10.0, 'review_scores_value': 10.0, 'license': None, 'instant_bookable': 'f', 'calculated_host_listings_count': 1, 'calculated_host_listings_count_entire_homes': 0, 'calculated_host_listings_count_private_rooms': 1, 'calculated_host_listings_count_shared_rooms': 0, 'reviews_per_month': 1.42}, {'index': 1, 'id': 12351, 'listing_url': 'https://www.airbnb.com/rooms/12351', 'scrape_id': 20210410042103, 'last_scraped': '2021-04-15', 'name': 'Sydney City & Harbour at the door', 'description': "Come stay with Vinh & Stuart (Awarded as one of Australia's top hosts by Airbnb CEO Brian Chesky & ...
# [2021-05-21 02:38:26,206] {base.py:132} INFO - COMMIT

# %% [markdown]
# # Ad-hoc

# %%
path = raw_data_dir / '2021-03-04'
df = pd.read_csv(path.with_suffix('.gz'), compression='gzip')
path = raw_data_dir / '2021-03-04_1000'
df.head(1000).to_csv(path.with_suffix('.gz'), compression='gzip', index=False)

# %%
path = raw_data_dir / '2021-04-10'
df = pd.read_csv(path.with_suffix('.gz'), compression='gzip')
path = raw_data_dir / '2021-04-10_1000'
df.head(1000).to_csv(path.with_suffix('.gz'), compression='gzip', index=False)

# %%
for path in raw_data_dir.glob('*.gz'):
    print(path)
    df = pd.read_csv(path, compression='gzip')
    df.head(1000).to_csv(path.parent.joinpath(f'{path.stem}_1000').with_suffix('.gz'), 
                         compression='gzip')
# Out:
# /home/jovyan/work/data/raw/2020-05-09.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">44</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">62</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">63</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">95</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# /home/jovyan/work/data/raw/2020-06-11.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">43</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">61</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">62</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">94</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# /home/jovyan/work/data/raw/2020-07-14.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">50</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">59</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">60</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">90</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# /home/jovyan/work/data/raw/2020-08-20.gz
# /home/jovyan/work/data/raw/2020-09-10.gz
# /home/jovyan/work/data/raw/2020-10-11.gz
# /home/jovyan/work/data/raw/2020-11-05.gz
# /home/jovyan/work/data/raw/2020-12-14.gz
# /home/jovyan/work/data/raw/2021-01-10.gz
# /home/jovyan/work/data/raw/2021-02-08.gz
# /home/jovyan/work/data/raw/2021-03-04.gz
# /home/jovyan/work/data/raw/2021-04-10.gz

# %% [markdown]
# # Get common fields
#
# Get the intersection of the columns for all 12 files.

# %%
common_fields = set(df.columns)
common_fields
# Out:
# {'Unnamed: 0',
#  'Unnamed: 0.1',
#  'access',
#  'accommodates',
#  'availability_30',
#  'availability_365',
#  'availability_60',
#  'availability_90',
#  'bathrooms',
#  'bed_type',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'calendar_last_scraped',
#  'calendar_updated',
#  'cancellation_policy',
#  'city',
#  'cleaning_fee',
#  'country',
#  'country_code',
#  'description',
#  'experiences_offered',
#  'extra_people',
#  'first_review',
#  'guests_included',
#  'has_availability',
#  'host_about',
#  'host_acceptance_rate',
#  'host_has_profile_pic',
#  'host_id',
#  'host_identity_verified',
#  'host_is_superhost',
#  'host_listings_count',
#  'host_location',
#  'host_name',
#  'host_neighbourhood',
#  'host_picture_url',
#  'host_response_rate',
#  'host_response_time',
#  'host_since',
#  'host_thumbnail_url',
#  'host_total_listings_count',
#  'host_url',
#  'host_verifications',
#  'house_rules',
#  'id',
#  'instant_bookable',
#  'interaction',
#  'is_business_travel_ready',
#  'is_location_exact',
#  'jurisdiction_names',
#  'last_review',
#  'last_scraped',
#  'latitude',
#  'license',
#  'listing_url',
#  'longitude',
#  'market',
#  'maximum_maximum_nights',
#  'maximum_minimum_nights',
#  'maximum_nights_avg_ntm',
#  'medium_url',
#  'minimum_maximum_nights',
#  'minimum_minimum_nights',
#  'minimum_nights_avg_ntm',
#  'monthly_price',
#  'name',
#  'neighborhood_overview',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'notes',
#  'number_of_reviews',
#  'number_of_reviews_l30d',
#  'number_of_reviews_ltm',
#  'picture_url',
#  'price',
#  'property_type',
#  'require_guest_phone_verification',
#  'require_guest_profile_picture',
#  'requires_license',
#  'review_scores_accuracy',
#  'review_scores_checkin',
#  'review_scores_cleanliness',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_rating',
#  'review_scores_value',
#  'reviews_per_month',
#  'room_type',
#  'scrape_id',
#  'security_deposit',
#  'smart_location',
#  'space',
#  'square_feet',
#  'state',
#  'street',
#  'summary',
#  'thumbnail_url',
#  'transit',
#  'weekly_price',
#  'xl_picture_url',
#  'zipcode'}

# %%
for path in raw_data_dir.glob('*1000.gz'):
    print(path)
    common_fields = common_fields.intersection(set(pd.read_csv(path, compression='gzip').columns))
# Out:
# /home/jovyan/work/data/raw/2020-05-09_1000.gz
# /home/jovyan/work/data/raw/2020-06-11_1000.gz
# /home/jovyan/work/data/raw/2020-07-14_1000.gz
# /home/jovyan/work/data/raw/2020-08-20_1000.gz
# /home/jovyan/work/data/raw/2020-09-10_1000.gz
# /home/jovyan/work/data/raw/2020-10-11_1000.gz
# /home/jovyan/work/data/raw/2020-11-05_1000.gz
# /home/jovyan/work/data/raw/2020-12-14_1000.gz
# /home/jovyan/work/data/raw/2021-01-10_1000.gz
# /home/jovyan/work/data/raw/2021-02-08_1000.gz
# /home/jovyan/work/data/raw/2021-03-04_1000.gz
# /home/jovyan/work/data/raw/2021-04-10_1000.gz

# %%
common_fields
# Out:
# {'Unnamed: 0',
#  'accommodates',
#  'availability_30',
#  'availability_365',
#  'availability_60',
#  'availability_90',
#  'bathrooms',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'calendar_last_scraped',
#  'calendar_updated',
#  'description',
#  'first_review',
#  'has_availability',
#  'host_about',
#  'host_acceptance_rate',
#  'host_has_profile_pic',
#  'host_id',
#  'host_identity_verified',
#  'host_is_superhost',
#  'host_listings_count',
#  'host_location',
#  'host_name',
#  'host_neighbourhood',
#  'host_picture_url',
#  'host_response_rate',
#  'host_response_time',
#  'host_since',
#  'host_thumbnail_url',
#  'host_total_listings_count',
#  'host_url',
#  'host_verifications',
#  'id',
#  'instant_bookable',
#  'last_review',
#  'last_scraped',
#  'latitude',
#  'license',
#  'listing_url',
#  'longitude',
#  'maximum_maximum_nights',
#  'maximum_minimum_nights',
#  'maximum_nights_avg_ntm',
#  'minimum_maximum_nights',
#  'minimum_minimum_nights',
#  'minimum_nights_avg_ntm',
#  'name',
#  'neighborhood_overview',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'picture_url',
#  'price',
#  'property_type',
#  'review_scores_accuracy',
#  'review_scores_checkin',
#  'review_scores_cleanliness',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_rating',
#  'review_scores_value',
#  'reviews_per_month',
#  'room_type',
#  'scrape_id'}

# %%
df.head(1000).longitude.describe()
# Out:
# count    1000.000000
# mean      151.226992
# std         0.067555
# min       150.698210
# 25%       151.202840
# 50%       151.239990
# 75%       151.270510
# max       151.337730
# Name: longitude, dtype: float64

# %%
path = raw_data_dir / '2020-07-14_1000.gz'
df = pd.read_csv(path, compression='gzip')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 104 columns):
#  #    Column                                        Dtype
# ---   ------                                        -----
#  0    Unnamed: 0                                    int64
#  1    Unnamed: 0.1                                  int64
#  2    id                                            int64
#  3    listing_url                                   object
#  4    scrape_id                                     float64
#  5    last_scraped                                  object
#  6    name                                          object
#  7    description                                   object
#  8    neighborhood_overview                         object
#  9    picture_url                                   object
#  10   host_id                                       int64
#  11   host_url                                      object
#  12   host_name                                     object
#  13   host_since                                    object
#  14   host_location                                 object
#  15   host_about                                    object
#  16   host_response_time                            object
#  17   host_response_rate                            object
#  18   host_acceptance_rate                          object
#  19   host_is_superhost                             object
#  20   host_thumbnail_url                            object
#  21   host_picture_url                              object
#  22   host_neighbourhood                            object
#  23   host_listings_count                           float64
#  24   host_total_listings_count                     float64
#  25   host_verifications                            object
#  26   host_has_profile_pic                          object
#  27   host_identity_verified                        object
#  28   neighbourhood                                 object
#  29   neighbourhood_cleansed                        object
#  30   neighbourhood_group_cleansed                  float64
#  31   latitude                                      float64
#  32   longitude                                     float64
#  33   property_type                                 object
#  34   room_type                                     object
#  35   accommodates                                  int64
#  36   bathrooms                                     float64
#  37   summary                                       object
#  38   space                                         object
#  39   experiences_offered                           object
#  40   notes                                         object
#  41   transit                                       object
#  42   access                                        object
#  43   interaction                                   object
#  44   house_rules                                   object
#  45   thumbnail_url                                 float64
#  46   medium_url                                    float64
#  47   xl_picture_url                                float64
#  48   street                                        object
#  49   city                                          object
#  50   state                                         object
#  51   zipcode                                       float64
#  52   market                                        object
#  53   smart_location                                object
#  54   country_code                                  object
#  55   country                                       object
#  56   is_location_exact                             object
#  57   bed_type                                      object
#  58   square_feet                                   float64
#  59   price                                         int64
#  60   weekly_price                                  object
#  61   monthly_price                                 object
#  62   security_deposit                              object
#  63   cleaning_fee                                  object
#  64   guests_included                               float64
#  65   extra_people                                  object
#  66   minimum_minimum_nights                        int64
#  67   maximum_minimum_nights                        int64
#  68   minimum_maximum_nights                        int64
#  69   maximum_maximum_nights                        int64
#  70   minimum_nights_avg_ntm                        float64
#  71   maximum_nights_avg_ntm                        float64
#  72   calendar_updated                              object
#  73   has_availability                              object
#  74   availability_30                               int64
#  75   availability_60                               int64
#  76   availability_90                               int64
#  77   availability_365                              int64
#  78   calendar_last_scraped                         object
#  79   number_of_reviews                             int64
#  80   number_of_reviews_ltm                         int64
#  81   number_of_reviews_l30d                        float64
#  82   first_review                                  object
#  83   last_review                                   object
#  84   review_scores_rating                          float64
#  85   review_scores_accuracy                        float64
#  86   review_scores_cleanliness                     float64
#  87   review_scores_checkin                         float64
#  88   review_scores_communication                   float64
#  89   review_scores_location                        float64
#  90   review_scores_value                           float64
#  91   license                                       float64
#  92   instant_bookable                              object
#  93   calculated_host_listings_count                int64
#  94   requires_license                              object
#  95   jurisdiction_names                            float64
#  96   is_business_travel_ready                      object
#  97   cancellation_policy                           object
#  98   require_guest_profile_picture                 object
#  99   require_guest_phone_verification              object
#  100  calculated_host_listings_count_entire_homes   int64
#  101  calculated_host_listings_count_private_rooms  int64
#  102  calculated_host_listings_count_shared_rooms   int64
#  103  reviews_per_month                             float64
# dtypes: float64(26), int64(20), object(58)
# memory usage: 812.6+ KB

# %%
df.price.dtype == 'O'
# Out:
# True

# %%
path = raw_data_dir / '2021-04-10.gz'
df = pd.read_csv(path, compression='gzip')

# %%
df.license
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 32674   NaN
# 32675   NaN
# 32676   NaN
# 32677   NaN
# 32678   NaN
# Name: license, Length: 32679, dtype: float64

# %% [markdown]
# # Check `id` uniqueness

# %%
for path in raw_data_dir.glob('*.gz'):
    print(path)
    df = pd.read_csv(path, compression='gzip')
    print(df.groupby('id').host_id.count().max())
# Out:
# /home/jovyan/work/data/raw/2020-05-09.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">44</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">62</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">63</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">95</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# 1
# /home/jovyan/work/data/raw/2020-06-11.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">43</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">61</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">62</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">94</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# 1
# /home/jovyan/work/data/raw/2020-07-14.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">50</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">59</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">60</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">90</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# 1
# /home/jovyan/work/data/raw/2020-08-20.gz
# 1
# /home/jovyan/work/data/raw/2020-09-10.gz
# 1
# /home/jovyan/work/data/raw/2020-10-11.gz
# 1
# /home/jovyan/work/data/raw/2020-11-05.gz
# 1
# /home/jovyan/work/data/raw/2020-12-14.gz
# 1
# /home/jovyan/work/data/raw/2021-01-10.gz
# 1
# /home/jovyan/work/data/raw/2021-02-08.gz
# 1
# /home/jovyan/work/data/raw/2021-03-04.gz
# 1
# /home/jovyan/work/data/raw/2021-04-10.gz
# 1

# %% [markdown]
# Seems that `id` is unique in all the files.

# %% [markdown]
# # Check which files have `stays`

# %%
for path in raw_data_dir.glob('*.gz'):
    print(path)
    df = pd.read_csv(path, compression='gzip')
    print(df.groupby('id').host_id.count().max())
# Out:
# /home/jovyan/work/data/raw/2020-05-09.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">44</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">62</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">63</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">95</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# 1
# /home/jovyan/work/data/raw/2020-06-11.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">43</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">61</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">62</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">94</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# 1
# /home/jovyan/work/data/raw/2020-07-14.gz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; font-weight: bold">/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:</span><span style="color: #808000; font-weight: bold">3169</span><span style="color: #808000; font-weight: bold"> DtypeWarning</span><span style="color: #808000">: Columns </span><span style="color: #808000; font-weight: bold">(</span><span style="color: #808000; font-weight: bold">50</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">59</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">60</span><span style="color: #808000">,</span><span style="color: #808000; font-weight: bold">90</span><span style="color: #808000; font-weight: bold">)</span><span style="color: #808000"> have mixed types.Specify dtype option on import or set </span><span style="color: #808000">low_memory</span><span style="color: #808000">=</span><span style="color: #808000; font-style: italic">False</span><span style="color: #808000">.</span>
# </pre>
# 1
# /home/jovyan/work/data/raw/2020-08-20.gz
# 1
# /home/jovyan/work/data/raw/2020-09-10.gz
# 1
# /home/jovyan/work/data/raw/2020-10-11.gz
# 1
# /home/jovyan/work/data/raw/2020-11-05.gz
# 1
# /home/jovyan/work/data/raw/2020-12-14.gz
# 1
# /home/jovyan/work/data/raw/2021-01-10.gz
# 1
# /home/jovyan/work/data/raw/2021-02-08.gz
# 1
# /home/jovyan/work/data/raw/2021-03-04.gz
# 1
# /home/jovyan/work/data/raw/2021-04-10.gz
# 1
